# %% [markdown]
# # Test Notebook for Assignment 1
#
# Importing some packages to start:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 1st, I'll read a csv of cell morphology from a piece of Castanea leaf

# %%
df = pd.read_csv('MLC_FLMNH00115_Fagaceae_Castanea_ashei_grp_Results_WithFilenames_trimmed_2MAD.csv')

# %% [markdown]
# Then, I'll use the Head function to show what's in the file

# %%
df.head()
# Out:
#    Unnamed: 0  X     File_Names  \
# 0           1  1  0001-0033.roi
# 1           2  2  0002-0048.roi
# 2           3  3  0003-0075.roi
# 3           4  4  0004-0090.roi
# 4           5  5  0005-0080.roi
#
#                                           File_Paths  ROI     Area  Perim.  \
# 0  ROI Sets/MLC_FLMNH00115_Fagaceae_Castanea_ashe...    1  304.120  66.485
# 1  ROI Sets/MLC_FLMNH00115_Fagaceae_Castanea_ashe...    2  420.180  80.032
# 2  ROI Sets/MLC_FLMNH00115_Fagaceae_Castanea_ashe...    3  448.959  81.307
# 3  ROI Sets/MLC_FLMNH00115_Fagaceae_Castanea_ashe...    4  515.686  89.565
# 4  ROI Sets/MLC_FLMNH00115_Fagaceae_Castanea_ashe...    5  571.344  91.765
#
#         BX      BY   Width  ...  Circ.   Feret   FeretX  FeretY  FeretAngle  \
# 0   33.117   1.948  24.675  ...  0.865  26.475  102.474  13.093     157.346
# 1  171.429   3.571  27.597  ...  0.824  28.550  530.758  76.413      29.219
# 2   67.532  10.390  23.052  ...  0.853  28.464  253.255  32.377      99.757
# ...

# %% [markdown]
# Then, I'll plot a histogram of the cell perimeter for all cells measured.

# %%
plt.hist(df["Perim."])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
